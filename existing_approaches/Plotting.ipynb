# %%
# Re-import necessary libraries after execution state reset
import numpy as np
import matplotlib.pyplot as plt

# Define function to create radar chart
def create_radar_chart(categories, values_dict, title):
    num_vars = len(categories)
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

    # Close the chart
    angles += angles[:1]

    fig, ax = plt.subplots(figsize=(7, 7), subplot_kw=dict(polar=True))

    for label, values in values_dict.items():
        values += values[:1]
        ax.plot(angles, values, label=label, linewidth=2)
        ax.fill(angles, values, alpha=0.3)

    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(categories)
    ax.set_title(title, fontsize=14)
    ax.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))

    plt.show()

# Define categories (metrics)
categories = ["accuracy", "balanced_accuracy", "weighted_f1", "macro_f1", "roc_auc"]

# Define values for each selection method (averages from last row in each dataset)
values_dict = {
    "top10_youdens_j": [0.619997, 0.672623, 0.665222, 0.549706, 0.661165],
    "avg_youdens_j": [0.686244, 0.689753, 0.713572, 0.592380, 0.685864],
    "max_youdens_j": [0.698437, 0.683970, 0.737053, 0.597473, 0.673916],
    "majority_youdens_j": [0.701686, 0.679119, 0.735090, 0.593049, 0.684422],
}

# Create radar chart
create_radar_chart(categories, values_dict, "Comparison of Selection Methods on Performance Metrics")

# %%
# Re-import necessary libraries after execution state reset
import numpy as np
import matplotlib.pyplot as plt

# Define function to create radar chart
def create_radar_chart(categories, values_dict, title):
    num_vars = len(categories)
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

    # Close the chart
    angles += angles[:1]

    fig, ax = plt.subplots(figsize=(7, 7), subplot_kw=dict(polar=True))

    for label, values in values_dict.items():
        values += values[:1]
        ax.plot(angles, values, label=label, linewidth=2)
        ax.fill(angles, values, alpha=0.3)

    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(categories)
    ax.set_title(title, fontsize=14)
    ax.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))

    plt.show()

# Define categories (metrics)
categories = ["accuracy", "balanced_accuracy", "weighted_f1", "macro_f1", "roc_auc"]

# Define values for each selection method (averages from last row in each dataset)
values_dict = {
    "top10_max_f1": [0.633510, 0.671112, 0.677512, 0.557716, 0.661165],
    "avg_max_f1": [0.802308, 0.678916, 0.811607, 0.653449, 0.685864],
    "max_max_f1": [0.730960, 0.677220, 0.763228, 0.616096, 0.673916],
    "majority_max_f1": [0.769186, 0.677649, 0.789646, 0.636015, 0.684422],
}

# Create radar chart
create_radar_chart(categories, values_dict, "Comparison of Selection Methods on Performance Metrics")

# %%
# Re-define values_dict after execution state reset
values_dict = {
    "top10_youdens_j": [0.619997, 0.672623, 0.665222, 0.549706, 0.661165],
    "top10_max_f1": [0.633510, 0.671112, 0.677512, 0.557716, 0.661165],
    "avg_youdens_j": [0.686244, 0.689753, 0.713572, 0.592380, 0.685864],
    "avg_max_f1": [0.802308, 0.678916, 0.811607, 0.653449, 0.685864],
    "max_youdens_j": [0.698437, 0.683970, 0.737053, 0.597473, 0.673916],
    "max_max_f1": [0.730960, 0.677220, 0.763228, 0.616096, 0.673916],
    "majority_youdens_j": [0.701686, 0.679119, 0.735090, 0.593049, 0.684422],
    "majority_max_f1": [0.769186, 0.677649, 0.789646, 0.636015, 0.684422],
}

# Define function to create radar chart with customized radial limits
def create_radar_chart_with_custom_limits(categories, values_dict, title, min_value=0.4, max_value=1.0):
    num_vars = len(categories)
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

    # Close the chart
    angles += angles[:1]

    fig, ax = plt.subplots(figsize=(7, 7), subplot_kw=dict(polar=True))

    for label, values in values_dict.items():
        values = values + values[:1]  # Close the chart for each line
        ax.plot(angles, values, label=label, linewidth=2)
        ax.fill(angles, values, alpha=0.3)

    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(categories)
    ax.set_ylim(min_value, max_value)  # Set custom radial limits

    ax.set_title(title, fontsize=14)
    ax.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))

    plt.show()

# Create radar chart with adjusted radial limits (starting from 0.4)
create_radar_chart_with_custom_limits(categories, values_dict, "Comparison of Selection Methods on Performance Metrics", min_value=0.4)
